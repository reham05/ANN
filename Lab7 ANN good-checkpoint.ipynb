# %%
import numpy as np
#Q1 a:
def logsigmoid(n):
    output = 1 / (1 + np.exp(-n))
    return output

def logsiglayer(W1,p,b1):
    n=(np.dot(W1,p))+b1
    a1=logsigmoid(n)
    return a1

#Q1 b:
def purelin(n):
    return n

def linearlayer(W2,a1,b2):
    n=(np.dot(W2,a1))+b2
    a2=purelin(n)
    return a2

# %%
#Q2
def forwardpropagation(p, W1, b1, W2, b2):
    a0= p
    a1= logsiglayer(W1,p,b1)
    a2= linearlayer(W2,a1,b2)
    return a0, a1, a2

# %%
#Q3
def dlogsig(n):
    a=(1-n)*n.T
    return a

def dpurelin(n):
    return 1

# %%
#Q4
def backpropagation(F2, t, a, F1, w2):
    s2 = (-2*F2)*(t-a)
    s1 = np.dot(F1, np.transpose(W2))*s2
    return s1, s2

# %%
#Q5
def updateparams(W1, W2, b1, b2, s1, s2, a0, a1, a2, alpha):
    W1= W1 - (alpha *s1)*np.transpose(a0)
    b1= b1-alpha*s1
    W2= W2-alpha*(np.dot(s2, a1.T))
    b2= b2-alpha*s2
    return W1, b1, W2, b2

# %%
#Q6
def backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha):
    a0, a1, a2 = forwardpropagation(p, W1, b1, W2, b2)
    f1= dlogsig(a1)
    F1= np.diag(f1)
    F2= dpurelin(a2)
    s1, s2= backpropagation(F2, t, a2, F1, W2)
    W1, b1, W2, b2= updateparams(W1, W2, b1, b2, s1, s2, a0, a1, a2, alpha)
    
    print("W1= ",W1)
    print("b1= ",b1)
    print("W2= ",W2)
    print("b2= ",b2)

# %%
#Q7 
#1
W1= np.random.rand(2,1)
b1= np.random.rand(2,1)
W2= np.random.rand(1,2)
b2= np.random.rand(1,1)

p= -2
t= 0
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.57825022]
#  [0.59207864]]
# b1=  [[0.09340996]
#  [0.68218269]]
# W2=  [[0.59698193 0.01618274]]
# b2=  [[0.38371068]]

# %%
#Q7
#2
W1=  [[0.57825022], [0.59207864]]
b1=  [[0.09340996], [0.68218269]]
W2=  [[0.59698193, 0.01618274]]
b2=  [[0.38371068]]

p=-1.5
t=0.006
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.60112067]
#  [0.61494909]]
# b1=  [[0.07816299]
#  [0.66693572]]
# W2=  [[ 0.56078688 -0.03527319]]
# b2=  [[0.26903219]]

# %%
#Q7
#3
W1=  [[0.60112067], [0.61494909]]
b1=  [[0.07816299], [0.66693572]]
W2=  [[ 0.56078688, -0.03527319]]
b2=  [[0.26903219]]


p=-1
t=0.29
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.60526734]
#  [0.61909576]]
# b1=  [[0.07401632]
#  [0.66278905]]
# W2=  [[ 0.54816019 -0.05267806]]
# b2=  [[0.23510415]]

# %%
#Q7
#4
W1=  [[0.60526734], [0.61909576]]
b1=  [[0.07401632], [0.66278905]]
W2=  [[ 0.54816019, -0.05267806]]
b2=  [[0.23510415]]


p=-0.5
t=0.617
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.60318545]
#  [0.61701387]]
# b1=  [[0.07818009]
#  [0.66695282]]
# W2=  [[ 0.5632212  -0.03271187]]
# b2=  [[0.26909475]]

# %%
#Q7
#5
W1=  [[0.60318545], [0.61701387]]
b1=  [[0.07818009], [0.66695282]]
W2=  [[ 0.5632212,  -0.03271187]]
b2=  [[0.26909475]]

p=0
t=1.0
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.60318545]
#  [0.61701387]]
# b1=  [[0.09043743]
#  [0.67921016]]
# W2=  [[0.61100895 0.02807156]]
# b2=  [[0.3610765]]

# %%
#6
W1=  [[0.60318545], [0.61701387]]
b1=  [[0.09043743], [0.67921016]]
W2=  [[0.61100895, 0.02807156]]
b2=  [[0.3610765]]

p=0.5
t=1.38
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.61285658]
#  [0.626685  ]]
# b1=  [[0.1097797 ]
#  [0.69855243]]
# W2=  [[0.68666009 0.12043894]]
# b2=  [[0.48784388]]

# %%
#7
W1=  [[0.61285658], [0.626685  ]]
b1=  [[0.1097797 ], [0.69855243]]
W2=  [[0.68666009, 0.12043894]]
b2=  [[0.48784388]]

p=1
t=1.707
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.63549468]
#  [0.6493231 ]]
# b1=  [[0.1324178 ]
#  [0.72119053]]
# W2=  [[0.77575673 0.22500265]]
# b2=  [[0.62019434]]

# %%
#8
W1=  [[0.63549468], [0.6493231 ]]
b1=  [[0.1324178 ], [0.72119053]]
W2=  [[0.77575673, 0.22500265]]
b2=  [[0.62019434]]

p=1.5
t=1.92
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.66344753]
#  [0.67727595]]
# b1=  [[0.15105303]
#  [0.73982576]]
# W2=  [[0.85496448 0.31452401]]
# b2=  [[0.72614887]]

# %%
#9
W1=  [[0.66344753], [0.67727595]]
b1=  [[0.15105303], [0.73982576]]
W2=  [[0.85496448, 0.31452401]]
b2=  [[0.72614887]]

p=2
t=2.0
alpha= 0.1
backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)
# Out:
# W1=  [[0.68249801]
#  [0.69632643]]
# b1=  [[0.16057827]
#  [0.749351  ]]
# W2=  [[0.90343711 0.36752642]]
# b2=  [[0.78567836]]

# %%
import numpy as np

# Initialize weights and biases
W1 = np.random.rand(2, 1)
b1 = np.random.rand(2, 1)
W2 = np.random.rand(1, 2)
b2 = np.random.rand(1, 1)

# Data points and targets
data = [
    (-2, 0.0),
    (-1.5, 0.006),
    (-1, 0.29),
    (-0.5, 0.617),
    (0, 1.0),
    (0.5, 1.38),
    (1, 1.707),
    (1.5, 1.92),
    (2, 2.0)
]

# Learning rate
alpha = 0.01  # Reduced learning rate

# Activation functions
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

# Backpropagation algorithm
def backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha):
    for _ in range(1000):  # Just for demonstration, normally you would use a convergence criterion
        # Forward pass
        h = np.dot(W1, np.array([[p]])).reshape(2, 1) + b1
        a = sigmoid(h)
        y = np.dot(W2, a) + b2
        E = 0.5 * (t - y) ** 2

        # Backward pass
        delta2 = -(t - y) * sigmoid_derivative(y)
        delta1 = np.dot(W2.T, delta2) * sigmoid_derivative(a)

        # Update weights and biases
        W2 -= alpha * np.dot(delta2, a.T)
        b2 -= alpha * delta2
        W1 -= alpha * np.dot(delta1, np.array([[p]]).T)
        b1 -= alpha * delta1

# Iterate through data points
for p, t in data:
    backpropagatealgorithm(W1, W2, b1, b2, p, t, alpha)

# Print converged weights and biases
print("Converged W1:")
print(W1)
print("Converged b1:")
print(b1)
print("Converged W2:")
print(W2)
print("Converged b2:")
print(b2)
# Out:
# Converged W1:
# [[0.44499039]
#  [0.96617319]]
# Converged b1:
# [[0.68575551]
#  [0.43448359]]
# Converged W2:
# [[-0.10229031  0.9204844 ]]
# Converged b2:
# [[0.24319318]]
