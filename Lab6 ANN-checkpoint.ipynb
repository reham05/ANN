# %%
import numpy as np
#Q1
def logsigmoid(n):
    return 1.0/(1+np.exp(-n))

def logsiglayer(w1,p,b1):
    a=np.dot(w1,p)+b1
    return logsigmoid

# %%
#Q2
def purlin(n):
    return n

def linearlayer(w2,a1,b2):
    a=np.dot(w2,a1)+b2
    return logsigmoid(a)

# %%
#Q3
import matplotlib.pyplot as plt

w1=[[10],[10]]
b1=[[-10],[10]]

w2=[1,1]
b2=0
p=np.array([np.linspace(-2,2)])

a1=logsiglayer(w1,p,b1)
linearlayer(w2,a1,b2)
a2=linearlayer(w2,a1,b2)

plt.figure(figsize=((10,8)))
plt.scatter(p,a2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       9 p=np.array([np.linspace(-2,2)])
#      11 a1=logsiglayer(w1,p,b1)
# ---> 12 linearlayer(w2,a1,b2)
#      13 a2=linearlayer(w2,a1,b2)
#      15 plt.figure(figsize=((10,8)))
#
# Cell In[6], line 6, in linearlayer(w2, a1, b2)
#       5 def linearlayer(w2,a1,b2):
# ----> 6     a=np.dot(w2,a1)+b2
#       7     return logsigmoid(a)
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# TypeError: unsupported operand type(s) for *: 'int' and 'function'
